# %% [markdown]
# # Reproduce the Laplace package
# The Laplace package facilitates the application of Laplace approximations for entire neural networks, subnetworks of neural networks, or just their last layer. This project reproduces the Laplace package for learning purposes. </br>
# This notebook shows how the reproduced Laplace can be used for parameter posterior approximation, hyper-parameter tuning, and prediction. Furthermore, the results are compared with Bayesian linear regression, and the Laplace package.
# ## References
# [Laplace: Laplace approximations for Deep Learning.](https://github.com/AlexImmer/Laplace/tree/main)
# ``` json
# @inproceedings{laplace2021,
#   title={Laplace Redux--Effortless {B}ayesian Deep Learning},
#   author={Erik Daxberger and Agustinus Kristiadi and Alexander Immer
#           and Runa Eschenhagen and Matthias Bauer and Philipp Hennig},
#   booktitle={{N}eur{IPS}},
#   year={2021}
# }
# @inproceedings{dangel2020backpack,
#     title     = {Back{PACK}: Packing more into Backprop},
#     author    = {Felix Dangel and Frederik Kunstner and Philipp Hennig},
#     booktitle = {International Conference on Learning Representations},
#     year      = {2020},
#     url       = {https://openreview.net/forum?id=BJlrF24twB}
# }
# ```

# %%
import torch 
import torch.nn as nn

import numpy as np 
import matplotlib.pyplot as plt

from LABDL.models import DNN, LinearSingleLayerModel, BayesianLinearRegression
from LABDL.data.generator import * 
from LABDL.laplace.curvatures import GGNCurvature, EFCurvature
from LABDL.laplace import FullLaplace, DiagLaplace
from LABDL.trainer.training import *

from laplace.curvature.backpack import BackPackGGN
from laplace import Laplace, marglik_training

# %%
# %reload_ext autoreload 
# %autoreload 2

# %% [markdown]
# ## Linear toy data
# First, we set up the training data for the problem with observation noise ($\sigma=0.2$):

# %%
slope, bias = 0.3, -0.7
X_train, y_train, train_loader, X_test = get_linear_examples(slope=slope, bias=bias)
fig, axs = plt.subplots()
fig.tight_layout()
axs.plot(X_train, y_train, 'o')
axs.set_title(f"training samples, f(x) = {slope}x+({bias}), sigma=0.2")
# Out:
# Text(0.5, 1.0, 'training samples, f(x) = 0.3x+(-0.7), sigma=0.2')

# %% [markdown]
# ## Models' set up: Bayesian linear regression, reproduced-Laplace, and Laplace.
# As mentioned earlier, three models are tested and compared: the Bayesian linear regression, the Laplace reproduced in this project, and the Laplace package.
# ### Bayesian linear regression
# We can use the Bayesian linear regression to analytical compute the posterior, the predictive, and the marginal likelihood, i.e. the data evidence.

# %%
blr = BayesianLinearRegression(X_train, y_train)

# %% [markdown]
# ### Reproduced-Laplace and the Laplace
# We use `pytorch` to train a simple linear layer with only two parameters, the weight and bias. The trained linear model will be our MAP estimate.

# %%
model = nn.Linear(1, 1)
print(model)
# fit model to obtain the MAP estimate parameter, the parameters are normally centered-distributed.
loss = train(model, train_loader)
print(f"sumed MSE Loss after training: {loss}")
for name, params in model.named_parameters():
    print(name)
    print(params)
# Out:
# Linear(in_features=1, out_features=1, bias=True)
# =============EPOCH 1==============
# loss_train: 1.939
# =============EPOCH 101==============
# loss_train: 0.053
# =============EPOCH 201==============
# loss_train: 0.050
# =============EPOCH 301==============
# loss_train: 0.050
# =============EPOCH 401==============
# loss_train: 0.050
# Finished Training.
# sumed MSE Loss after training: 38.79856299608946
# weight
# Parameter containing:
# tensor([[0.2964]], requires_grad=True)
# bias
# Parameter containing:
# tensor([-0.6594], requires_grad=True)

# %%
la = FullLaplace(model, H_approximation='GGN')
la.fit(train_loader)
# Out:
# [Parameter containing:
# tensor([[0.2964]], requires_grad=True), Parameter containing:
# tensor([-0.6594], requires_grad=True)]

# %%
latorch = Laplace(model, 'regression', subset_of_weights='all', hessian_structure='full')
latorch.fit(train_loader)

# %% [markdown]
# ### compare the results

# %%
mean_blr = blr.mean.flatten()
pos_blr = blr.posterior_precision.detach().numpy()

mean_la = la.mean.detach().numpy()
pos_la = la.posterior_precision.detach().numpy()

mean_latorch = latorch.mean.detach().numpy()
pos_latorch = latorch.posterior_precision.detach().numpy()

np.testing.assert_allclose(mean_blr, mean_la, atol=1e-1)
np.testing.assert_allclose(pos_blr, pos_la, atol=1e-3)

np.testing.assert_allclose(mean_la, mean_latorch, atol=1e-3)
np.testing.assert_allclose(pos_la, pos_latorch, atol=1e-3)

# %%
pred_mean_blr, pred_var_blr = blr.predict(X_test)
pred_mean_blr, pred_var_blr = pred_mean_blr.flatten().detach().numpy(), pred_var_blr.flatten().detach().numpy()

pred_mean_la, pred_var_la = la.predict(X_test)
pred_mean_la, pred_var_la = pred_mean_la.flatten().detach().numpy(), pred_var_la.flatten().detach().numpy()
print(pred_mean_la.shape, pred_var_la.shape)

pred_mean_latorch, pred_var_latorch = latorch(X_test)
pred_mean_latorch, pred_var_latorch = pred_mean_latorch.flatten().detach().numpy(), pred_var_latorch.flatten().detach().numpy()

np.testing.assert_allclose(pred_mean_blr, pred_mean_la, atol=1e-1)
np.testing.assert_allclose(pred_var_blr, pred_var_la, atol=1e-3)
np.testing.assert_allclose(pred_mean_la, pred_mean_latorch, atol=1e-3)
np.testing.assert_allclose(pred_var_la, pred_var_latorch, atol=1e-3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 pred_mean_blr, pred_var_blr = blr.predict(X_test)
#       2 pred_mean_blr, pred_var_blr = pred_mean_blr.flatten().detach().numpy(), pred_var_blr.flatten().detach().numpy()
# ----> 4 pred_mean_la, pred_var_la = la.predict(X_test)
#       5 pred_mean_la, pred_var_la = pred_mean_la.flatten().detach().numpy(), pred_var_la.flatten().detach().numpy()
#       6 print(pred_mean_la.shape, pred_var_la.shape)
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/baselaplace.py:251, in BaseLaplace.predict(self, X, pred_type, glm_link_approx, num_samples)
#     248         return samples.mean(dim=0), None
#     250 elif pred_type == 'glm':
# --> 251     f_mu, f_cov = self._glm_output_distribution(X)
#     252     # + \sigma^2 I?
#     253     if self.regression:
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/baselaplace.py:311, in BaseLaplace._glm_output_distribution(self, X)
#     300 def _glm_output_distribution(self, X):
#     301     """
#     302     The output distribution of a linearized neural network, p(f*|x*, D)\sim N(f*; f_{\theta_{MAP}}, J(x*)^T\Sigma J(x*))
#     303
#    (...)
#     309     f_cov of shape (batch_size, out_features, out_features)
#     310     """
# --> 311     Js, f_mu = self.backend.jacobians(X)
#     312     f_cov =  torch.einsum("npc, pq, nqk-> nck", Js, self.posterior_covariance, Js)
#     313     return f_mu, f_cov
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/curvatures/curvatureinterface.py:52, in CurvatureInterface.jacobians(self, x)
#      49     out_c.backward(retain_graph=True) # store the output in `grad_batch` of shape (batch_size, gradients_size)
#      51 for param in self.model.parameters():
# ---> 52     tmp_Js.append(param.grad_batch.detach().flatten(start_dim=1)) # of shape (batch_size, each_param_size), where parameters are flattened to be one-dimensional tensors.
#      53 cat_Js = torch.cat(tmp_Js, dim=1) # of shape (batch_size, num_params)
#      54 Js_list.append(cat_Js)
#
# AttributeError: 'Parameter' object has no attribute 'grad_batch'

# %% [markdown]
# ## Hyper-parameter tuning with MLL

# %%
n_epochs = 1000

# %%
# Bayesian linear regression
log_sigma = torch.ones(1, requires_grad=True) # log std deviation of the regression Gaussian noise
log_prior_var = torch.ones(1, requires_grad=True) # log variance of parameter prior 
lr = 1e-1
optimizer = torch.optim.Adam([log_prior_var, log_sigma], lr=lr)
for epoch in range(n_epochs): 
    optimizer.zero_grad()
    neg_log_marg_lik = -blr.log_marginal_likelihood(log_prior_var.exp(), log_sigma.exp())
    neg_log_marg_lik.backward()
    optimizer.step()

# %%
print(blr.sigma_noise)
print(blr.prior_precision)
# Out:
# tensor([0.2113], grad_fn=<ExpBackward0>)
# tensor([3.4178], grad_fn=<MulBackward0>)

# %%
# LA-based
log_sigma = torch.ones(1, requires_grad=True) # log std deviation of the regression Gaussian noise
log_prior_var = torch.ones(1, requires_grad=True) # log variance of parameter prior 
lr = 1e-1
optimizer = torch.optim.Adam([log_prior_var, log_sigma], lr=lr)
for epoch in range(n_epochs): 
    optimizer.zero_grad()
    neg_log_marg_lik = - la.log_marginal_likelihood(log_prior_var.exp(), log_sigma.exp())
    neg_log_marg_lik.backward()
    optimizer.step()

# %%
print(la.sigma_noise)
print(la.prior_precision)
# Out:
# tensor([0.2143], grad_fn=<ExpBackward0>)
# tensor([3.8192], grad_fn=<MulBackward0>)

# %%
log_prior_, log_sigma_ = torch.ones(1, requires_grad=True), torch.ones(1, requires_grad=True)
hyper_optimizer = torch.optim.Adam([log_prior_, log_sigma_], lr=1e-1)
for i in range(n_epochs):
    hyper_optimizer.zero_grad()
    neg_marglik = - latorch.log_marginal_likelihood(log_prior_.exp(), log_sigma_.exp())
    neg_marglik.backward()
    hyper_optimizer.step()

# %%
print(log_sigma_.exp())
print(log_prior_.exp())
# Out:
# tensor([0.2143], grad_fn=<ExpBackward0>)
# tensor([3.8192], grad_fn=<ExpBackward0>)

# %%
sigma_noise_blr = blr.sigma_noise.detach().numpy()
sigma_noise_la = la.sigma_noise.detach().numpy()
prior_precision_blr = blr.prior_precision.detach().numpy()
prior_precision_la = la.prior_precision.detach().numpy()

# %%
np.testing.assert_allclose(sigma_noise_blr, sigma_noise_la, atol=1e-2)
np.testing.assert_allclose(prior_precision_blr, prior_precision_la, atol=1e-2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 np.testing.assert_allclose(sigma_noise_blr, sigma_noise_la, atol=1e-2)
# ----> 2 np.testing.assert_allclose(prior_precision_blr, prior_precision_la, atol=1e-2)
#
#     [... skipping hidden 1 frame]
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-03/6a700484/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File /share/apps/anaconda-ci/fgci-centos7-anaconda/software/anaconda/2023-03/6a700484/lib/python3.10/site-packages/numpy/testing/_private/utils.py:797, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict)
#     793         err_msg += '\n' + '\n'.join(remarks)
#     794         msg = build_err_msg([ox, oy], err_msg,
#     795                             verbose=verbose, header=header,
#     796                             names=('x', 'y'), precision=precision)
# --> 797         raise AssertionError(msg)
#     798 except ValueError:
#     799     import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0.01
#
# Mismatched elements: 1 / 1 (100%)
# Max absolute difference: 0.4014306
# Max relative difference: 0.10510797
#  x: array([3.417791], dtype=float32)
#  y: array([3.819221], dtype=float32)

# %%
def plot(X_train, y_train, X_test, f_mu, pred_std):
    fig, axs = plt.subplots()
    fig.tight_layout()
    axs.plot(X_train, y_train, 'o')
    axs.plot(X_test, f_mu, 'o')
    axs.fill_between(X_test.flatten(), f_mu - 2*pred_std, f_mu + 2*pred_std, alpha=0.2)

# %%
f_mu, f_var = latorch(X_test)
f_mu = f_mu.squeeze().detach().cpu().numpy()
f_sigma = f_var.squeeze().sqrt().cpu().numpy()
pred_std = np.sqrt(f_sigma**2 + latorch.sigma_noise.item()**2)

plot(X_train, y_train, X_test, f_mu, pred_std)

# %%
la_pred_mean, la_pred_var = la.predict(X_test)
la_pred_mean = la_pred_mean.flatten().detach().numpy()
la_pred_std = 2*torch.sqrt(torch.diag(la_pred_var)).flatten().detach().numpy()

plot(X_train, y_train, X_test, la_pred_mean, la_pred_std)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 la_pred_mean, la_pred_var = la.predict(X_test)
#       2 la_pred_mean = la_pred_mean.flatten().detach().numpy()
#       3 la_pred_std = 2*torch.sqrt(torch.diag(la_pred_var)).flatten().detach().numpy()
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/baselaplace.py:251, in BaseLaplace.predict(self, X, pred_type, glm_link_approx, num_samples)
#     248         return samples.mean(dim=0), None
#     250 elif pred_type == 'glm':
# --> 251     f_mu, f_cov = self._glm_output_distribution(X)
#     252     # + \sigma^2 I?
#     253     if self.regression:
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/baselaplace.py:311, in BaseLaplace._glm_output_distribution(self, X)
#     300 def _glm_output_distribution(self, X):
#     301     """
#     302     The output distribution of a linearized neural network, p(f*|x*, D)\sim N(f*; f_{\theta_{MAP}}, J(x*)^T\Sigma J(x*))
#     303
#    (...)
#     309     f_cov of shape (batch_size, out_features, out_features)
#     310     """
# --> 311     Js, f_mu = self.backend.jacobians(X)
#     312     f_cov =  torch.einsum("npc, pq, nqk-> nck", Js, self.posterior_covariance, Js)
#     313     return f_mu, f_cov
#
# File /scratch/work/zhangx18/Bayesian-Deep-Learning/LABDL/laplace/curvatures/curvatureinterface.py:51, in CurvatureInterface.jacobians(self, x)
#      48     out_c.backward(retain_graph=True) # store the output in `grad_batch` of shape (batch_size, gradients_size)
#      50 for param in self.model.parameters():
# ---> 51     tmp_Js.append(param.grad_batch.detach().flatten(start_dim=1)) # of shape (batch_size, each_param_size), where parameters are flattened to be one-dimensional tensors.
#      52 cat_Js = torch.cat(tmp_Js, dim=1) # of shape (batch_size, num_params)
#      53 Js_list.append(cat_Js)
#
# AttributeError: 'Parameter' object has no attribute 'grad_batch'

# %% [markdown]
# ## shape test of the curvature computing w.r.t. the model and log likelihood

# %%
def test_ggncurvature_shape(model: nn.Module, 
                           train_loader):
    """GGNCurvature methods shape test
    Args: 
    model: note that in BackPack, self-defined module should be extended. 
    """
    interface = GGNCurvature(model, regression=True, stochastic=False)
    batch = next(iter(train_loader))
    features, targets = batch
    
    num_params = sum([len(param.flatten()) for param in model.parameters()])
    batch_size, out_features = targets.shape
    print(batch_size)
    print(num_params)
    print(out_features)
    
    print("GGNCurvature, regression=True, stochastic=True:")
    print("=====gradients=====")
    gradients, loss = interface.gradients(features, targets)
    print("gradients.shape:", gradients.shape)
    assert gradients.shape == (batch_size, num_params)
        
    print("======jacobians=====")
    Js, out = interface.jacobians(features)
    print("jacobians.shape:", Js.shape)
    assert Js.shape == (batch_size, num_params, out_features)
    
    print("=====full=====")
    ggn_full, loss = interface.full(features, targets)
    print("ggn_full.shape:", ggn_full.shape)
    assert ggn_full.shape == (num_params, num_params)
                     
    print("=====diag=====")
    ggn_diag, loss = interface.diag(features, targets)
    print("ggn_diag.shape:", ggn_diag.shape)
    assert ggn_diag.shape == (num_params,)
        
    #print("=====kron=====")
    #gnn_kron, loss = interface.kron(features, targets)

test_ggncurvature_shape(model, train_loader)

# %%
def test_efcurvature_shape(model: nn.Module, 
                           train_loader):
    """EFCurvature methods shape test. 
    Args: 
    model: note that in BackPack, Modules that do not represent an operation in the computation graph (for instance containers like Sequential) will not explicitly be extended.
    """
    interface = EFCurvature(model, regression=True, stochastic=False)
    batch = next(iter(train_loader))
    features, targets = batch
    
    num_params = sum([len(param.flatten()) for param in model.parameters()])
    batch_size, out_features = targets.shape
    print(batch_size)
    print(num_params)
    print(out_features)
    
    print("EFCurvature, regression=True, stochastic=True:")
    print("=====full=====")
    ef_full, loss = interface.full(features, targets)
    print("ef_full.shape:", ef_full.shape)
    assert ef_full.shape == (num_params, num_params)
                     
    print("=====diag=====")
    ef_diag, loss = interface.diag(features, targets)
    print("ef_diag.shape:", ef_diag.shape)
    assert ef_diag.shape == (num_params,)

test_efcurvature_shape(model, train_loader)

# %%
interface = GGNCurvature(model, regression=True, stochastic=False)
Js, out = interface.jacobians(X_test)
print("jacobians.shape:", Js.shape)
# Out:
# jacobians.shape: torch.Size([500, 2, 1])
